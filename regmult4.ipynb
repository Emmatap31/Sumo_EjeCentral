# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Tiempos_promedio.csv')

variables_independientes = ['GGrr (s)','yyrr (s)','rrGG (s)','rryy (s)']
variable_dependiente = 'Tiempo promedio'

X = data[variables_independientes]
y = data[variable_dependiente]

# %%
y
np.savetxt('y.csv', y)

# %%
modelo = make_pipeline( PolynomialFeatures(degree=4), LinearRegression())

# %%
modelo.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=4)),
#                 ('linearregression', LinearRegression())])

# %%
y_pred= modelo.predict(X)

# %%
y_pred
np.savetxt('yreg4.csv', y_pred)

# %%
y_pred
# Out:
# array([40.36773066, 38.96896892, 38.09308348, 43.22221909, 41.91480385,
#        41.97026954, 39.86845174, 40.55721882, 35.48280702, 43.51503826,
#        43.00836908, 36.86508989, 39.70921866, 43.22472279, 41.79554701,
#        44.06073842, 36.65286621, 44.06547181, 43.99390959, 38.01602674,
#        52.84069197, 47.86429865, 42.26585782, 41.06711798, 41.57702372,
#        37.19331388, 40.48955557, 34.04812053, 46.4519699 , 33.26617622,
#        39.23385266, 41.19858848, 45.70537796, 40.27059772, 42.92473005,
#        39.76995024, 43.3307439 , 36.44143838, 50.55158957, 41.71091873,
#        43.95239672, 40.06218268, 57.98824957, 35.36483905, 35.26531709,
#        47.55615942, 42.34385049, 42.735033  , 47.2052395 , 36.11739533,
#        43.09709808, 38.51211407, 48.2085853 , 42.34336269, 41.38836651,
#        36.40353137, 45.62300116, 44.44946029, 45.31096794, 46.80314426,
#        41.85466643, 43.5151413 , 34.18546679, 40.41087087, 44.2130882 ,
#        46.14226312, 44.06788919, 53.98414571, 34.84191826, 38.67796711,
#        45.59519758, 43.00580866, 43.45060881, 44.8697193 , 47.81340135,
#        40.2386594 , 44.75975092, 40.54550174, 41.7968345 , 42.86930986,
#        41.86240069, 37.23569857, 43.0672783 , 45.33462706, 40.11451251,
#        35.88576717, 36.11121119, 42.29936978, 44.3605319 , 44.33912486,
#        40.64775613, 42.78686171, 48.9895381 , 40.12118095, 44.29907902,
#        41.20043048, 40.60766535, 47.79966088, 35.62989887, 51.31489161,
#        41.08638351, 55.88576653, 44.10092519, 39.15470514, 32.57837067,
#        42.76909381, 52.92240556, 34.81526416, 39.28278901, 35.05994395,
#        38.49328291, 43.10280378, 42.50011182, 39.20395563, 38.68147889,
#        36.98923866, 39.72210415, 51.975106  , 45.27514307, 43.39987077,
#        44.18295521, 37.00270868, 39.39005523, 45.13249388, 37.64250821,
#        33.88108539, 43.07755074, 52.19116873, 38.36352889, 45.83594706,
#        33.79206828, 40.68406577, 48.16197373, 43.04645532, 36.55298584,
#        37.64853346, 40.11159823, 37.80555743, 41.82538229, 37.05788094,
#        44.46409086, 42.24039984, 37.06839493, 37.97182743, 37.33437083,
#        37.36532853, 50.10520671, 41.97397227, 38.95240824, 36.1108104 ,
#        40.00509719, 42.83787049, 34.00105921, 34.05026565, 36.39915613,
#        43.30962971, 45.95667485, 43.35763595, 43.27415323, 40.5138354 ,
#        39.314781  , 42.58990818, 39.88557198, 42.25799573, 47.84962709,
#        55.19139829, 33.08056891, 41.53926883, 36.38231904, 44.74702463,
#        56.82067734, 32.46519293, 39.82647658, 43.92232008, 40.66810297,
#        35.10716118, 41.40909389, 44.47177679, 38.67625762, 39.92316054,
#        46.59563099, 42.39749917, 36.13608154, 51.86715009, 45.19517382,
#        36.20251169, 42.71703373, 40.00390406, 39.56245842, 38.40185971,
#        43.11755696, 49.57475632, 36.29980256, 42.54120573, 47.25946872,
#        39.02517849, 44.4470657 , 49.81969784, 42.0953549 , 45.74145755,
#        40.80143745, 56.83053412, 50.95609181, 40.45242191, 42.37854162,
#        52.2679785 , 40.27898605, 39.59291613, 44.79790039, 39.09825575,
#        40.06432383, 41.9840119 , 43.55116376, 41.82221411, 35.94633254,
#        34.2022979 , 51.24551226, 39.63539898, 37.70291889, 40.61747657,
#        36.70031712, 50.67175678, 52.2889421 , 46.5843815 , 43.20020043,
#        44.03395706, 44.25796888, 51.7512023 , 39.80655154, 38.57307466,
#        42.01831819, 39.69607584, 32.65105105, 39.61139794, 33.86502843,
#        43.27019761, 42.78508177, 40.05860553, 48.81024678, 44.54634313,
#        52.97491908, 49.42159482, 51.02052149, 42.31961872, 37.21852974,
#        34.02092684, 39.62927132, 42.88469594, 47.87525895, 35.87750555,
#        41.85159642, 41.27736215, 43.96007488, 49.17618119, 36.11463813,
#        37.50824994, 44.63609625, 45.05985866, 34.04263338, 35.61199638,
#        36.76963895, 39.89704919, 38.0365177 , 33.49891017, 38.87544868,
#        40.13492159, 44.2757665 , 42.80474186, 43.98884486, 41.3994347 ,
#        50.09624504, 34.0148885 , 41.83581568, 41.42499011, 39.26436613])

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"Error cuadrático medio: {mse}")
print(f"R^2 = {r2}")
# Out:
# Error cuadrático medio: 1.2395812640056811
# R^2 = 0.9548371155980458

# %%
lin_reg = modelo.named_steps['linearregression']
poly_feat = modelo.named_steps['polynomialfeatures']

# %%
coefs = lin_reg.coef_
intercept = lin_reg.intercept_

# %%
feature_names = poly_feat.get_feature_names_out(['GGrr (s)', 'yyrr (s)', 'rrGG (s)', 'rryy (s)'])

# %%
feature_names
# Out:
# array(['1', 'GGrr (s)', 'yyrr (s)', 'rrGG (s)', 'rryy (s)', 'GGrr (s)^2',
#        'GGrr (s) yyrr (s)', 'GGrr (s) rrGG (s)', 'GGrr (s) rryy (s)',
#        'yyrr (s)^2', 'yyrr (s) rrGG (s)', 'yyrr (s) rryy (s)',
#        'rrGG (s)^2', 'rrGG (s) rryy (s)', 'rryy (s)^2', 'GGrr (s)^3',
#        'GGrr (s)^2 yyrr (s)', 'GGrr (s)^2 rrGG (s)',
#        'GGrr (s)^2 rryy (s)', 'GGrr (s) yyrr (s)^2',
#        'GGrr (s) yyrr (s) rrGG (s)', 'GGrr (s) yyrr (s) rryy (s)',
#        'GGrr (s) rrGG (s)^2', 'GGrr (s) rrGG (s) rryy (s)',
#        'GGrr (s) rryy (s)^2', 'yyrr (s)^3', 'yyrr (s)^2 rrGG (s)',
#        'yyrr (s)^2 rryy (s)', 'yyrr (s) rrGG (s)^2',
#        'yyrr (s) rrGG (s) rryy (s)', 'yyrr (s) rryy (s)^2', 'rrGG (s)^3',
#        'rrGG (s)^2 rryy (s)', 'rrGG (s) rryy (s)^2', 'rryy (s)^3',
#        'GGrr (s)^4', 'GGrr (s)^3 yyrr (s)', 'GGrr (s)^3 rrGG (s)',
#        'GGrr (s)^3 rryy (s)', 'GGrr (s)^2 yyrr (s)^2',
#        'GGrr (s)^2 yyrr (s) rrGG (s)', 'GGrr (s)^2 yyrr (s) rryy (s)',
#        'GGrr (s)^2 rrGG (s)^2', 'GGrr (s)^2 rrGG (s) rryy (s)',
#        'GGrr (s)^2 rryy (s)^2', 'GGrr (s) yyrr (s)^3',
#        'GGrr (s) yyrr (s)^2 rrGG (s)', 'GGrr (s) yyrr (s)^2 rryy (s)',
#        'GGrr (s) yyrr (s) rrGG (s)^2',
#        'GGrr (s) yyrr (s) rrGG (s) rryy (s)',
#        'GGrr (s) yyrr (s) rryy (s)^2', 'GGrr (s) rrGG (s)^3',
#        'GGrr (s) rrGG (s)^2 rryy (s)', 'GGrr (s) rrGG (s) rryy (s)^2',
#        'GGrr (s) rryy (s)^3', 'yyrr (s)^4', 'yyrr (s)^3 rrGG (s)',
#        'yyrr (s)^3 rryy (s)', 'yyrr (s)^2 rrGG (s)^2',
#        'yyrr (s)^2 rrGG (s) rryy (s)', 'yyrr (s)^2 rryy (s)^2',
#        'yyrr (s) rrGG (s)^3', 'yyrr (s) rrGG (s)^2 rryy (s)',
#        'yyrr (s) rrGG (s) rryy (s)^2', 'yyrr (s) rryy (s)^3',
#        'rrGG (s)^4', 'rrGG (s)^3 rryy (s)', 'rrGG (s)^2 rryy (s)^2',
#        'rrGG (s) rryy (s)^3', 'rryy (s)^4'], dtype=object)

# %%
for name, coef in zip(feature_names, coefs):
    print(f"{name}: {coef}")
print(f"intercepto: {intercept}")
# Out:
# 1: -9.30836955529869e-07
# GGrr (s): -5.4089336092350555
# yyrr (s): -1.644057700585777
# rrGG (s): -2.6645966838851205
# rryy (s): 38.54916557743239
# GGrr (s)^2: 0.24454068648595556
# GGrr (s) yyrr (s): 0.6134413816461085
# GGrr (s) rrGG (s): -0.11084512291382663
# GGrr (s) rryy (s): 0.353330792134275
# yyrr (s)^2: 2.0663982336487914
# yyrr (s) rrGG (s): 0.2549159251253804
# yyrr (s) rryy (s): -10.342848314302465
# rrGG (s)^2: 0.12575665359446475
# rrGG (s) rryy (s): -0.26483292322439483
# rryy (s)^2: -11.65707436381609
# GGrr (s)^3: -0.004549839842166718
# GGrr (s)^2 yyrr (s): -0.009543687089317143
# GGrr (s)^2 rrGG (s): 0.0022768023013291522
# GGrr (s)^2 rryy (s): -0.0007751604882898071
# GGrr (s) yyrr (s)^2: 0.0045648947239659175
# GGrr (s) yyrr (s) rrGG (s): -0.012605457415333766
# GGrr (s) yyrr (s) rryy (s): -0.006419134762565275
# GGrr (s) rrGG (s)^2: 0.0010406881947891996
# GGrr (s) rrGG (s) rryy (s): -0.006728584100357264
# GGrr (s) rryy (s)^2: -0.0566619940395274
# yyrr (s)^3: -1.3259980407991223
# yyrr (s)^2 rrGG (s): 0.0478030592681662
# yyrr (s)^2 rryy (s): 2.1476459263776597
# yyrr (s) rrGG (s)^2: -0.007838619509669563
# yyrr (s) rrGG (s) rryy (s): 0.08326487241010395
# yyrr (s) rryy (s)^2: 0.15921046117932233
# rrGG (s)^3: -0.0012623296812439792
# rrGG (s)^2 rryy (s): -0.010948281554127422
# rrGG (s) rryy (s)^2: 0.18501169603850148
# rryy (s)^3: 1.7794233381758664
# GGrr (s)^4: 2.8624130834042916e-05
# GGrr (s)^3 yyrr (s): 3.756077495520316e-05
# GGrr (s)^3 rrGG (s): -7.711487821637775e-06
# GGrr (s)^3 rryy (s): 5.049236545318081e-06
# GGrr (s)^2 yyrr (s)^2: 0.0004385262221477948
# GGrr (s)^2 yyrr (s) rrGG (s): 4.588056131638041e-05
# GGrr (s)^2 yyrr (s) rryy (s): 0.00016433165112372805
# GGrr (s)^2 rrGG (s)^2: -1.9803619913716375e-05
# GGrr (s)^2 rrGG (s) rryy (s): 2.582467883449624e-05
# GGrr (s)^2 rryy (s)^2: -0.00014413905633325896
# GGrr (s) yyrr (s)^3: -0.005616387943782164
# GGrr (s) yyrr (s)^2 rrGG (s): 0.0010459747411045717
# GGrr (s) yyrr (s)^2 rryy (s): -0.007458263946561378
# GGrr (s) yyrr (s) rrGG (s)^2: 2.087466040201491e-05
# GGrr (s) yyrr (s) rrGG (s) rryy (s): 7.045249792936303e-05
# GGrr (s) yyrr (s) rryy (s)^2: 0.005478939695867935
# GGrr (s) rrGG (s)^3: 3.876561363469477e-06
# GGrr (s) rrGG (s)^2 rryy (s): 3.116534562863649e-05
# GGrr (s) rrGG (s) rryy (s)^2: 0.00040068383953900666
# GGrr (s) rryy (s)^3: 0.002645382525256257
# yyrr (s)^4: 0.11363439134828315
# yyrr (s)^3 rrGG (s): -0.008363208749223
# yyrr (s)^3 rryy (s): 0.09216371051621544
# yyrr (s)^2 rrGG (s)^2: 0.000620062277461475
# yyrr (s)^2 rrGG (s) rryy (s): -0.01672651669232271
# yyrr (s)^2 rryy (s)^2: -0.30476506343104376
# yyrr (s) rrGG (s)^3: -7.265857209670656e-06
# yyrr (s) rrGG (s)^2 rryy (s): 0.0010639423398222103
# yyrr (s) rrGG (s) rryy (s)^2: -0.006263729378680513
# yyrr (s) rryy (s)^3: 0.19423909817278195
# rrGG (s)^4: 3.295429932492766e-06
# rrGG (s)^3 rryy (s): 2.5423122941292675e-05
# rrGG (s)^2 rryy (s)^2: 0.00046571637120784715
# rrGG (s) rryy (s)^3: -0.020223514312520674
# rryy (s)^4: -0.1275433099402521
# intercepto: 72.66964018305589

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
data2 = pd.read_csv("Nuevos_valores.csv")

# %%
variables_independientes = ['GGrr (s)','yyrr (s)','rrGG (s)','rryy (s)']
variable_dependiente = 'Tiempo promedio'

X_test = data2[variables_independientes]
y_test = data2[variable_dependiente]

# %%
y_pred= modelo.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Error cuadrático medio: {mse}")
print(f"R^2 = {r2}")
# Out:
# Error cuadrático medio: 2.9748391565852548
# R^2 = 0.8939866481575273

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
df_test = pd.read_csv('df_test.csv')
variables_independientes = ['GGrr (s)','yyrr (s)','rrGG (s)','rryy (s)']
variable_dependiente = 'Tiempo promedio'
X_test = df_test[variables_independientes]
y_test = df_test[variable_dependiente]
ypred = modelo.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, ypred)
r2 = r2_score(y_test, ypred)
print(mse)
print(r2)
# Out:
# 2.8398864180416723
# 0.8977245242184541

# %%
import numpy as np
np.savetxt('yreg4.csv', ypred)

# %%
y_test
# Out:
# 0      42.273792
# 1      47.816987
# 2      37.672950
# 3      41.208770
# 4      44.885861
#          ...
# 120    36.594094
# 121    38.672269
# 122    35.886336
# 123    38.795082
# 124    38.685061
# Name: Tiempo promedio, Length: 125, dtype: float64

# %%
import numpy as np
np.savetxt('y_test.csv', y_test)
